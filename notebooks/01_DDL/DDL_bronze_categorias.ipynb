# %%
# %sql
CREATE TABLE IF NOT EXISTS iniciacion_deportiva.bronze.categorias_raw (
    categoria_id   STRING,
    nombre         STRING,
    path_from_root STRING COMMENT 'Jerarquía completa',   -- JSON crudo de la API
    _source        STRING,
    ingested_at    TIMESTAMP
) USING DELTA;
