# %%
# %sql

--Creacion de schemas

USE CATALOG iniciacion_deportiva;
CREATE SCHEMA IF NOT EXISTS bronze
COMMENT 'Esquema para datos crudos sin procesar';
CREATE SCHEMA IF NOT EXISTS silver
COMMENT 'Esquema para datos limpios, validados y con tipos correctos';
CREATE SCHEMA IF NOT EXISTS gold
COMMENT 'Esquema para datos agregados y métricas de negocio';
